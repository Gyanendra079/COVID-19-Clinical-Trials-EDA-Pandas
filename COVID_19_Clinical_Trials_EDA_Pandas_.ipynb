# %% [markdown]
# <a href="https://colab.research.google.com/github/Gyanendra079/COVID-19-Clinical-Trials-EDA-Pandas/blob/main/COVID_19_Clinical_Trials_EDA_Pandas_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Dataset Description

# %% [markdown]
# ClinicalTrials.gov is a database of privately and publicly funded clinical studies
# conducted around the world. It is maintained by the National Institute of Health. All data
# is publicly available and the site provides a direct download feature which makes it
# super easy to use relevant data for analysis.
# <p>This dataset consists of clinical trials related to COVID 19 studies presented on the
# site.</p>

# %% [markdown]
# ###Exploratory Data Analysis of COVID-19 Clinical Trials
# ####<b>1. Objective</b>
# The objective is to explore the dataset to gain insights into the characteristics of
# COVID-19 clinical trials, such as their status, phases, study designs, and
# demographics.

# %% [markdown]
# <b>2. Importing Libraries and Loading Data</b>
# <p>First, you'll need to import the necessary libraries and load your dataset.</p>

# %%
# import important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('COVID clinical trials.csv')

# %% [markdown]
# <b>3. Initial Data Exploration</b>
#
# Start by exploring the basic structure and content of the dataset.

# %%
# First Five row of the dataset
df.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1     2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2     3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3     4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4     5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
#
#         Acronym                  Status         Study Results  \
# 0   COVID-IDNow  Active, not recruiting  No Results Available
# 1      COVID-19      Not yet recruiting  No Results Available
# 2   TAC-COVID19              Recruiting  No Results Available
# 3      COVID-19  Active, not recruiting  No Results Available
# 4  TMF-COVID-19              Recruiting  No Results Available
#
#                                           Conditions  \
# 0                                            Covid19
# ...

# %%
# Check the column names and datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5783 entries, 0 to 5782
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rank                     5783 non-null   int64
#  1   NCT Number               5783 non-null   object
#  2   Title                    5783 non-null   object
#  3   Acronym                  2480 non-null   object
#  4   Status                   5783 non-null   object
#  5   Study Results            5783 non-null   object
#  6   Conditions               5783 non-null   object
#  7   Interventions            4897 non-null   object
#  8   Outcome Measures         5748 non-null   object
#  9   Sponsor/Collaborators    5783 non-null   object
#  10  Gender                   5773 non-null   object
#  11  Age                      5783 non-null   object
#  12  Phases                   3322 non-null   object
#  13  Enrollment               5749 non-null   float64
# ...

# %%
# Check the statistics of numerical columns
df.describe()
# Out:
#               Rank    Enrollment
# count  5783.000000  5.749000e+03
# mean   2892.000000  1.831949e+04
# std    1669.552635  4.045437e+05
# min       1.000000  0.000000e+00
# 25%    1446.500000  6.000000e+01
# 50%    2892.000000  1.700000e+02
# 75%    4337.500000  5.600000e+02
# max    5783.000000  2.000000e+07

# %%
# Check the statistics for categorical columns
df.describe(include='object')
# Out:
#          NCT Number                                              Title  \
# count          5783                                               5783
# unique         5783                                               5775
# top     NCT04680000  Acalabrutinib Study With Best Supportive Care ...
# freq              1                                                  2
#
#          Acronym      Status         Study Results Conditions  \
# count       2480        5783                  5783       5783
# unique      2338          12                     2       3067
# top     COVID-19  Recruiting  No Results Available   COVID-19
# freq          47        2805                  5747        720
#
#                  Interventions Outcome Measures  \
# count                     4897             5748
# unique                    4337             5687
# top     Other: No intervention        Mortality
# freq                        32                5
#
# ...

# %%
print(df.columns.to_list())
# Out:
# ['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results', 'Conditions', 'Interventions', 'Outcome Measures', 'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment', 'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date', 'Primary Completion Date', 'Completion Date', 'First Posted', 'Results First Posted', 'Last Update Posted', 'Locations', 'Study Documents', 'URL']

# %% [markdown]
# Brief explaination for each column in the COVID clinical trials dataset
# 1.   <b>Rank</b>: Serial number or ranking order of the clinical trials.
# 1.   <b>NCT Number</b>: Unique identifier assigned to each clinical trial by ClinicalTrials.gov (e.g., NCT04785898).
# 1.   <b>Title</b>: Full title of the clinical trial.
# 2.   <b>Acronym</b>: Shortened form or abbreviation of the study title, if available.
# 2.   <b>Status</b>: Current recruitment status (e.g., Recruiting, Completed, Not yet recruiting).
# 1.   <b>Study Results</b>: Indicates whether results have been posted (e.g., "No Results Available").
# 1.   <b>Conditions</b>: The medical condition(s) being studied (e.g., COVID-19).
# 1.   <b>Interventions</b>: Treatments, drugs, or procedures being tested.
# 1.   <b>Outcome Measures</b>: Key goals or metrics used to evaluate the success of the intervention.
# 2.   <b>Sponsor/Collaborators</b>: Institutions or organizations conducting or supporting the study.
# 2.   <b>Gender</b>: Gender eligibility of participants (e.g., All, Male, Female).
# 2.   <b>Age</b>: Age range of eligible participants (e.g., 18 Years and older).
# 2.   <b>Phases</b>: The trial phase (e.g., Phase 1, 2, 3), mostly relevant to drug development.
# 1.   <b>Enrollment</b>: Number of participants enrolled or planned to be enrolled.
# 2.   <b>Funded Bys</b>: Indicates funding source (e.g., NIH, Industry).
# 1.   <b>Study Type</b>: Type of study (e.g., Interventional, Observational).
# 2.   <b>Study Designs</b>: Describes how the study is designed (e.g., Randomized, Masking).
# 1.   <b>Other IDs</b>: Additional study IDs assigned by sponsors or regulatory bodies.
# 2.   <b>Start Date</b>: When the study officially began.
# 1.   <b>Primary Completion Date</b>: When the final participant was examined for the primary outcome.
# 2.   <b>Completion Date</b>: When the study is fully completed.
# 1.   <b>First Posted</b>: Date the trial was first posted on ClinicalTrials.gov.
# 2.   <b>Results First Posted</b>: Date the results were first posted, if applicable.
# 1.   <b>Last Update Posted</b>: Most recent date of study information update.
# 2.   <b>Locations</b>: Geographic locations where the study is being conducted.
# 1.   <b>Study Documents</b>: Links to additional documents like protocols or statistical analysis plans.
# 2.   <b>URL</b>: Direct link to the study’s ClinicalTrials.gov webpage.

# %% [markdown]
# ####Data Cleaning and Optimization
# To clean and optimize the clinical trials dataset, dropping irrelevant or sparse columns, fixing data types, handling missing values and extracting and standardizing location information.

# %%
from collections import Counter

# %%
# Drop columns with too many missing values or irrelevant for EDA
drop_cols = ['Acronym', 'Study Documents', 'Other IDs', 'Results First Posted']
df.drop(columns=drop_cols, inplace=True)

# %%
# Convert date columns to datetime
date_cols = ['Start Date', 'Primary Completion Date', 'Completion Date', 'First Posted', 'Last Update Posted']
for col in date_cols:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# fill missing values
df['Enrollment'] = df['Enrollment'].fillna(0).astype(int)
df['Phases'] = df['Phases'].fillna('Not Reported')
df['Gender'] = df['Gender'].fillna('All')
df['Outcome Measures'] = df['Outcome Measures'].fillna('Not Reported')

# %%
# Optimize data types
category_cols = ['Status', 'Study Results', 'Gender', 'Age', 'Phases', 'Funded Bys', 'Study Type']
for col in category_cols:
    df[col] = df[col].astype('category')

# Extract countries from Locations
def extract_countries(location):
    if pd.isnull(location):
        return []
    parts = [loc.strip() for loc in location.split('|')]
    countries = [loc.split(',')[-1].strip() for loc in parts if ',' in loc]
    return countries

df['Countries'] = df['Locations'].apply(extract_countries)

# Standardize common country name variants
country_aliases = {
    "USA": "United States",
    "U.S.A.": "United States",
    "UK": "United Kingdom",
    "Hong Kong": "China",
    "Russian Federation": "Russia",
    "Republic of Korea": "South Korea"
}
df['Countries'] = df['Countries'].apply(
    lambda countries: [country_aliases.get(c, c) for c in countries]
)

# Add total country count for each row
df['Country Count'] = df['Countries'].apply(len)

# Create a trial count per country DataFrame for EDA
all_countries = [country for sublist in df['Countries'] for country in sublist]
country_counts = pd.Series(Counter(all_countries), name='Trial Count').reset_index()
country_counts.columns = ['Country', 'Trial Count']

# %% [markdown]
# ####Distribution of Study Phases,Study Type and Status

# %% [markdown]
# Understanding distribution of study phases provides insight into the clinical maturity of COVID-19 trials. <p>Clinical trials are typically divided into phases (e.g., Phase 1, Phase 2, etc.) that represent different stages of drug or intervention development:<p>

# %%
# set plot style
sns.set(style="whitegrid")

# Bar Chart for the Study Phases u
plt.figure(figsize=(10, 5))
phase_counts = df['Phases'].value_counts()
sns.barplot(x=phase_counts.index, y=phase_counts.values, palette="viridis")
plt.title("Distribution of Study Phases", fontsize=14)
plt.xlabel("Study Phase", fontsize=12)
plt.ylabel("Number of Trials", fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-62-620052428.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=phase_counts.index, y=phase_counts.values, palette="viridis")

# %% [markdown]
# The distribution is skewed—often with more trials in early phases (Phase 1 or Phase 2) which reflecta the urgency of finding a cure during the pandemic. Phase 3 trials, which are crucial for regulatory approval, are fewer in number but represent the most rigorously tested interventions.

# %%
# Group 'Expanded Access' as 'Other'
df['Study Type'] = df['Study Type'].apply(lambda s: 'Other' if 'Expanded' in s else s)

# Prepare data
study_type_pct = df['Study Type'].value_counts(normalize=True).mul(100).reset_index()
study_type_pct.columns = ['Study Type', 'Percentage']

# Plot
plt.figure(figsize=(8, 5))
sns.barplot(data=study_type_pct, x='Study Type', y='Percentage', palette='viridis')
plt.title("COVID-19 Study Types")
plt.ylabel("% of Total Studies")
plt.xlabel("Study Type")
plt.xticks(rotation=0)
plt.show()
# Out:
# /tmp/ipython-input-63-202699182.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=study_type_pct, x='Study Type', y='Percentage', palette='viridis')

# %% [markdown]
# The dataset reveals that interventional studies form the majority, which is expected given the global effort to test new therapies and vaccines. However, observational studies also play a vital role in understanding the natural course of COVID-19, risk factors, and long-term effects.

# %%
# Prepare data
status_pct = df['Status'].value_counts(normalize=True).mul(100).reset_index()
status_pct.columns = ['Status', 'Percentage']

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(data=status_pct, x='Status', y='Percentage', palette='magma')
plt.title("Current Status of COVID-19 Studies")
plt.ylabel("% of Total Studies")
plt.xlabel("Study Status")
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipython-input-64-908823439.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=status_pct, x='Status', y='Percentage', palette='magma')

# %% [markdown]
# Various insights we can understand from the distribution are:
# * The majority of studies are either Completed or Recruiting, reflecting the progress in exploration for COVID-19 interventions.
# * Smaller proportions of Not Yet Recruiting, Terminated, or Withdrawn trials reveal operational or scientific hurdles.
# *Various types of status reveals the dynamic nature of clinical research during a global health crisis.

# %% [markdown]
# ####Study Duration Analysis
# To understand how long COVID-19 clinical trials typically last, we can calculate duration of each study by computing the difference between the Start Date and the Completion Date which provides insight for timeline required for executing clinical trials during a global health emergency.

# %%
# Convert 'Start Date' and 'Completion Date' to datetime format
df['Start Date'] = pd.to_datetime(df['Start Date'], errors='coerce')
df['Completion Date'] = pd.to_datetime(df['Completion Date'], errors='coerce')

# Calculate study duration in days
df['Study Duration (days)'] = (df['Completion Date'] - df['Start Date']).dt.days

# Filter out missing or negative durations
valid_durations = df['Study Duration (days)'].dropna()
valid_durations = valid_durations[valid_durations >= 0]

# Plot the distribution using seaborn
plt.figure(figsize=(10, 6))
sns.histplot(valid_durations, bins=30, kde=True, color='skyblue')     # kde option gives a smooth pdf curve
plt.title("Distribution of COVID-19 Study Durations")
plt.xlabel("Study Duration (days)")
plt.ylabel("Number of Studies")
plt.show()

# %% [markdown]
# Maximum studies show durations of few months to over a year, depending on the study phase, complexity, and recruitment size. While shorter durations are often associated with early-phase or observational studies, longer durations generally indicate late-phase trials or those involving long-term outcome tracking. The wide variability in study duration highlights both the urgency and diversity of research efforts conducted during the COVID-19 pandemic.

# %% [markdown]
# #### Top Countries Conducting Trials
# To identify countries involved in COVID-19 clinical trials visualize the geographic distribution of research efforts. This analysis helps reveal the global landscape of COVID-19 clinical research, highlighting nations took  charge in conducting trials thus offering insights into global healthcare responsiveness and resource allocation during the pandemic.

# %%
# Checking various values for locations
df.loc[1:5,'Locations']
# Out:
# 1         Cimedical, Barranquilla, Atlantico, Colombia
# 2    Ospedale Papa Giovanni XXIII, Bergamo, Italy|P...
# 3    Hong Kong Sanatorium & Hospital, Hong Kong, Ho...
# 4                         CHR Orléans, Orléans, France
# 5    Vinmec Research Institute of Stem cell and Gen...
# Name: Locations, dtype: object

# %%
import re
from collections import Counter

# Load dataset
#df = pd.read_csv("COVID clinical trials.csv")

# Drop NaNs from 'Locations' column
locations = df['Locations'].dropna()

# Extract country names as they are present in the last of locations column
country_list = []

for entry in locations:
    # Split by '|' to handle multiple locations in one entry
    parts = entry.split('|')
    for part in parts:
        # Extract country as the last item in the comma-separated string
        segments = part.strip().split(',')
        if segments:
            country = segments[-1].strip()
            country_list.append(country)

# Count occurrences of each country
country_counts = Counter(country_list)
top_countries = country_counts.most_common(10)  # Top 10 countries

# Convert to DataFrame for plotting
country_df = pd.DataFrame(top_countries, columns=['Country', 'Number of Trials'])

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(data=country_df, x='Number of Trials', y='Country', palette='crest')
plt.title("Top 10 Countries Conducting COVID-19 Clinical Trials")
plt.xlabel("Number of Trials")
plt.ylabel("Country")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-67-1127217875.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=country_df, x='Number of Trials', y='Country', palette='crest')

# %% [markdown]
# Countries like France, Spain, Italty are intermediate in comparison to United States which has highest recorded Clinical Trails which basically present them on higher scale as their medical research facilities have more funding which mark them as leaders of the pharmaceutical global market .

# %% [markdown]
# ####Find out the 20 most frequently used interventions in COVID-19 clinical trials.

# %%
from itertools import chain

# Clean and parse the 'Interventions' column
df['Interventions'] = df['Interventions'].fillna('')
df['Intervention List'] = df['Interventions'].apply(lambda x: [i.strip() for i in x.split('|') if i.strip()])

# Flatten the intervention list and count
all_interventions = list(chain.from_iterable(df['Intervention List']))
intervention_counts = Counter(all_interventions)

# Create a DataFrame with top 20
top_20_interventions = pd.DataFrame(intervention_counts.most_common(20), columns=['Intervention', 'Count'])

# display the datakk
top_20_interventions
# Out:
#                        Intervention  Count
# 0                     Drug: Placebo    354
# 1                    Other: Placebo    147
# 2          Drug: Hydroxychloroquine    104
# 3               Biological: Placebo     60
# 4                  Drug: Remdesivir     43
# 5                Drug: Azithromycin     39
# 6                 Drug: Tocilizumab     36
# 7            Other: No intervention     32
# 8                  Drug: Ivermectin     31
# 9         Drug: Placebo oral tablet     31
# 10          Other: Standard of Care     29
# 11             Other: Questionnaire     29
# 12                Drug: Favipiravir     27
# 13  Biological: Convalescent plasma     23
# 14  Biological: Convalescent Plasma     23
# 15              Drug: Dexamethasone     19
# 16          Other: Standard of care     18
# 17                    Other: Survey     18
# 18                 Drug: Enoxaparin     17
# 19               Drug: Nitazoxanide     17

# %% [markdown]
# ####Visualize the most frequently used interventions in COVID-19 clinical trials

# %%
# Rename for consistency
df.rename(columns={'Interventions': 'Intervention Type'}, inplace=True)

# Drop missing values
df['Intervention Type'] = df['Intervention Type'].dropna()

# Normalize and explode multi-value entries
df['Intervention Type'] = df['Intervention Type'].str.lower()
df['Intervention Type'] = df['Intervention Type'].str.split(';|,')
df = df.explode('Intervention Type')
df['Intervention Type'] = df['Intervention Type'].str.strip()

# Count frequency of each intervention type
intervention_counts = df['Intervention Type'].value_counts().reset_index()
intervention_counts.columns = ['Intervention Type', 'Count']

# Plot top 15
plt.figure(figsize=(12, 6))
sns.barplot(data=intervention_counts.head(15), x='Intervention Type', y='Count', palette='viridis')
plt.title('Top 15 Most Frequently Used Interventions in COVID-19 Clinical Trials')
plt.xlabel('Intervention Type')
plt.ylabel('Number of Trials')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-69-669975783.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=intervention_counts.head(15), x='Intervention Type', y='Count', palette='viridis')

# %% [markdown]
# In the analysis of COVID-19 clinical trials
# * Drug-based interventions emerged as the most frequently used, underscoring a global emphasis on repurposing or developing therapeutic treatments.
# * Biological interventions, particularly vaccines and monoclonal antibodies, also ranked highly, reflecting the parallel focus on prevention.

# %% [markdown]
# ####Various types of demographics

# %% [markdown]
# What are the most commonly studied outcome measures in COVID-19 clinical trials and identify the primary goals or endpoints researchers are measuring to evaluate the effectiveness or impact of the intervention ?

# %%
# Drop null values in Outcome Measures
outcomes = df['Outcome Measures'].dropna()

# Split entries by semicolon or comma
all_outcomes = []
for entry in outcomes:
    split_items = re.split(r';|,', entry)
    cleaned = [item.strip().lower() for item in split_items if item.strip()]
    all_outcomes.extend(cleaned)                                                 # normalize and collect all outcomes

# Count frequency of each outcome measure
outcome_counter = Counter(all_outcomes)
most_common_outcomes = outcome_counter.most_common(20)

# Convert to DataFrame for better presentation
top_outcomes_df = pd.DataFrame(most_common_outcomes, columns=['Outcome Measure', 'Frequency'])

# Display result
top_outcomes_df
# Out:
#                                       Outcome Measure  Frequency
# 0                                              day 14         89
# 1                                              day 28         82
# 2                                             month 3         54
# 3                                             month 6         54
# 4                                        not reported         36
# 5                                                  14         31
# 6                                                   2         30
# 7                                              day 21         30
# 8                                            at day 7         28
# 9                                       positive rate         26
# 10  day 42 after prime vaccination of recombinant ...         26
# 11                                             day 35         26
# 12                                             day 42         26
# ...

# %% [markdown]
# * Commonly studied outcomes include inflammatory biomarkers like IL-6 and D-dimer, clinical severity indicators such as “moderate,” “severity,” and “death,” as well as mental health aspects like anxiety and depression.
# * Hospitalization metrics and follow-up timelines (e.g., day 14, day 28) are also frequently tracked, reflecting the importance of patient recovery duration.

# %% [markdown]
# ####Analyze the Gender Eligibility Distribution analysis grouped by Study Phases in the COVID clinical trials dataset

# %%
# Clean data: drop rows with missing values in 'Gender' or 'Phase'
df_clean = df.dropna(subset=['Gender', 'Phases'])

# Count of Gender per Study Phase
grouped = df_clean.groupby(['Phases', 'Gender']).size().reset_index(name='Count')

# Plot the grouped bar chart
plt.figure(figsize=(10, 6))
sns.barplot(data=grouped, x='Phases', y='Count', hue='Gender', palette='Set2')

# Chart customization
plt.title("Gender Eligibility Distribution Grouped by Study Phase")
plt.xlabel("Study Phase")
plt.ylabel("Number of Trials")
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-71-2705826017.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df_clean.groupby(['Phases', 'Gender']).size().reset_index(name='Count')

# %% [markdown]
# This analysis concludes various results as follows
# * Early-phase trials (like Phase 1) show slightly more gender-specific restrictions, likely due to safety concerns or reproductive health considerations
# * Analysis that most trials are inclusive of all genders, with this trend becoming more prominent in later phases such as Phase 3 and Phase 4.
# * The balanced distribution across phases reflects a commitment to gender inclusivity in clinical research, especially as trials progress toward broader public application

# %% [markdown]
# ####Clean and parse the Age column and categorize age ranges

# %%
# Inspect unique values
df['Age'].unique()
# Out:
# ['18 Years and older   (Adult, Older Adult)', 'Child, Adult, Older Adult', '18 Years to 48 Years   (Adult)', '18 Years to 75 Years   (Adult, Older Adult)', '18 Years to 45 Years   (Adult)', ..., '6 Months to 24 Months   (Child)', '18 Years to 34 Years   (Adult)', '12 Years to 22 Years   (Child, Adult)', '3 Months to 18 Years   (Child, Adult)', '8 Years to 20 Years   (Child, Adult)']
# Length: 417
# Categories (417, object): ['1 Month and older   (Child, Adult, Older Adult)', '1 Month to 100 Years   (Child, Adult, Older A...,
#                            '1 Month to 17 Years   (Child)', '1 Month to 18 Years   (Child, Adult)', ...,
#                            'up to 85 Years   (Child, Adult, Older Adult)', 'up to 89 Years   (Child, Adult, Older Adult)',
#                            'up to 90 Years   (Child, Adult, Older Adult)', 'up to 99 Years   (Child, Adult, Older Adult)']

# %%
# Standardize and categorize age ranges
def clean_age(age):
    age = str(age).lower().strip()
    if 'child' in age:
        return 'Child'
    elif 'adult' in age:
        return 'Adult'
    elif 'older' in age or 'senior' in age:
        return 'Older Adult'
    elif 'all' in age:
        return 'All Ages'
    elif 'years' in age:
        # Extract numbers
        parts = age.split('to')
        try:
            low = int(parts[0].strip().split()[0])
            high = int(parts[1].strip().split()[0]) if len(parts) > 1 else low
            if high < 18:
                return 'Child'
            elif 18 <= low <= 64:
                return 'Adult'
            else:
                return 'Older Adult'
        except:
            return 'Unknown'
    else:
        return 'Unknown'

df['Age Group'] = df['Age'].apply(clean_age)

# %%
print("\n Categorized Age Groups ")
df['Age Group'].value_counts(dropna=False)
# Out:
#  Categorized Age Groups
# Age Group
# Adult    5104
# Child    1080
# Name: count, dtype: int64

# %%
# Convert Enrollment to numeric
df['Enrollment'] = pd.to_numeric(df['Enrollment'], errors='coerce')

# Drop NaN enrollments
df_clean = df.dropna(subset=['Enrollment'])

# Summary statistics
print("=== Summary Statistics ===")
print(df_clean['Enrollment'].describe())
# Out:
# === Summary Statistics ===
# count    6.184000e+03
# mean     1.726493e+04
# std      3.901187e+05
# min      0.000000e+00
# 25%      6.000000e+01
# 50%      1.640000e+02
# 75%      5.257500e+02
# max      2.000000e+07
# Name: Enrollment, dtype: float64

# %%
# Categorize enrollment size into buckets
def categorize_enrollment(n):
    if n < 50:
        return 'Small (<50)'
    elif 50 <= n <= 500:
        return 'Medium (50–500)'
    else:
        return 'Large (>500)'

df_clean['Enrollment Category'] = df_clean['Enrollment'].apply(categorize_enrollment)

# Countplot for categorized enrollment
plt.figure(figsize=(8, 5))
sns.countplot(data=df_clean, x='Enrollment Category', order=['Small (<50)', 'Medium (50–500)', 'Large (>500)'], palette='Set2')
plt.title("Categorized Enrollment Sizes")
plt.xlabel("Enrollment Category")
plt.ylabel("Number of Trials")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-76-3276296157.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_clean, x='Enrollment Category', order=['Small (<50)', 'Medium (50–500)', 'Large (>500)'], palette='Set2')

# %% [markdown]
#  A smaller number of large-scale trials enroll more than 500 participants, contributing to a high mean and standard deviation. This indicates that while most studies are small to moderately sized, a few large-scale studies contribute disproportionately to the total enrolled population.

# %% [markdown]
# ####How various types of funders support specific study phases more often and  where the allocation of assets is done during different phases of trails?

# %%
# Group data: count trials by Phase and Funded Bys
heatmap_data = df.groupby(['Funded Bys', 'Phases']).size().unstack(fill_value=0)

# Plot heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, annot=True, fmt='d', cmap='viridis')
plt.title("Heatmap: Funding Source vs Study Phase")
plt.xlabel("Study Phase")
plt.ylabel("Funding Source")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-77-2034672753.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   heatmap_data = df.groupby(['Funded Bys', 'Phases']).size().unstack(fill_value=0)

# %% [markdown]
# The heatmap reveals a diverse landscape of funding support across COVID-19 study phases.
# * "Other" funders are academic or international institutions dominate trial support across the board, while industry players involves in later-phase trials.
# *Governmental funders like NIH and the U.S. Fed contribute more to early-stage or specialized research.
# * The scarcity of Phase 4 suggest the rapid and ongoing nature of pandemic-related interventions, with studies developing in their clinical phases.

# %% [markdown]
# ####Distribution of trails across various sectors (e.g., government, industry, academic institutions)?

# %%
def classify_sponsor(name):
    name = name.lower()
    if 'university' in name or 'institute' in name:
        return 'Academic'
    elif 'pharma' in name or 'inc' in name or 'llc' in name:
        return 'Industry'
    elif 'nih' in name or 'cdc' in name or 'ministry' in name:
        return 'Government'
    else:
        return 'Other'

sponsor_df = df['Sponsor/Collaborators'].dropna().apply(classify_sponsor)
sponsor_df.value_counts()
# Out:
# Sponsor/Collaborators
# Academic      3203
# Other         2403
# Industry       545
# Government      33
# Name: count, dtype: int64

# %% [markdown]
# Academic institutes helps in foundational research and creates the building block for others. Industry helps in product development which came later and government funds the reasearch and analysis and quick response in the time of emergency for the specific targeted role.

# %% [markdown]
# ####Analyse number of clinical trials over time based on the Start Date column and draw insights.

# %%
# Convert the chosen date column to datetime, coercing errors to NaT
df["Start Date"] = pd.to_datetime(df["Start Date"], errors="coerce")

# Drop rows where the date is not available
df = df.dropna(subset=["Start Date"])

# Create a new column grouping the date by year-month (for better aggregation)
df["YearMonth"] = df["Start Date"].dt.to_period("M")

# Count the number of trials per month
trial_counts = df.groupby("YearMonth").size().reset_index(name="Trial Count")
trial_counts["YearMonth"] = trial_counts["YearMonth"].astype(str)

# Plot the number of trials over time (line plot with markers)
plt.figure(figsize=(12, 6))
sns.lineplot(x="YearMonth", y="Trial Count", data=trial_counts, marker="o")
plt.title("Number of COVID-19 Trials Over Time")
plt.xlabel("Date (Year-Month)")
plt.ylabel("Number of Trials")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-79-705650401.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["YearMonth"] = df["Start Date"].dt.to_period("M")

# %% [markdown]
# The time series analysis as the trials have a rapid growth in the early phases and after reaching the peak amount it's decreases and become stable as the later phases have more targeted approach by the research community in response to covid-19.

# %%
# Normalize values in Study Results column
df['Study Results'] = df['Study Results'].str.strip().str.lower()

# Count how many studies have posted results
results_availability = df['Study Results'].value_counts()

# Time gap between Completion and Results First Posted
df['Primary Completion Date'] = pd.to_datetime(df['Primary Completion Date'], errors='coerce')
df['First Posted'] = pd.to_datetime(df['First Posted'], errors='coerce')

df_results = df.dropna(subset=['Completion Date', 'First Posted']).copy()

# Now safely compute delay
df_results['Posting Delay (days)'] = (df_results['First Posted'] - df_results['Completion Date']).dt.days

# Remove negative or unreasonable delays
df_results = df_results[df_results['Posting Delay (days)'] >= 0]

# %%
# --- Plot 1: Bar chart of availability ---
plt.figure(figsize=(6, 4))
sns.countplot(x=df['Study Results'], palette='pastel')
plt.title("Availability of Study Results")
plt.xlabel("Study Results Posted")
plt.ylabel("Number of Trials")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-81-311611775.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Study Results'], palette='pastel')

# %%
# --- Plot 2: Histogram of posting delay ---
plt.figure(figsize=(10, 6))
sns.histplot(df_results['Posting Delay (days)'], bins=30, kde=True, color='coral')
plt.title("Delay Between Completion and Results Posting")
plt.xlabel("Delay (Days)")
plt.ylabel("Number of Trials")
plt.tight_layout()
plt.show()

# Summary statistics of delay
df_results['Posting Delay (days)'].describe()
# Out:
# count    433.000000
# mean      50.806005
# std       65.246891
# min        0.000000
# 25%        9.000000
# 50%       26.000000
# 75%       67.000000
# max      418.000000
# Name: Posting Delay (days), dtype: float64

# %% [markdown]
# These results suggest there is significant portions of studies that have not posted their result and among the studies the delays are between 30 to 300 days.
# The highly skewed distribution clearly states that the majority of them reported the trials timely with few exception considering how much crucial is publish the trial in the global health crisis.

# %% [markdown]
# #####Text Analysis of Study Titles and Conditions using NLP for word clouds.

# %%
# !pip install pandas matplotlib wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS

# View available columns to adjust if needed
print(df.columns)

# Use appropriate column names
title_text = df['Title'].dropna().astype(str).str.lower()  # Replace 'Title' if your column is named differently
condition_text = df['Conditions'].dropna().astype(str).str.lower()

# Combine all text into a single string
combined_text = " ".join(title_text.tolist() + condition_text.tolist())

# Define stopwords
stopwords = set(STOPWORDS)
stopwords.update(['study', 'covid-19', 'trial', 'patients', 'infection', 'disease', 'treatment'])

# Generate word cloud
wordcloud = WordCloud(
    width=1000,
    height=500,
    background_color='white',
    stopwords=stopwords,
    colormap='viridis'
).generate(combined_text)

# Plot the word cloud
plt.figure(figsize=(14, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud of Study Titles and Conditions")
plt.tight_layout()
plt.show()
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Status', 'Study Results', 'Conditions',
#        'Intervention Type', 'Outcome Measures', 'Sponsor/Collaborators',
#        'Gender', 'Age', 'Phases', 'Enrollment', 'Funded Bys', 'Study Type',
#        'Study Designs', 'Start Date', 'Primary Completion Date',
#        'Completion Date', 'First Posted', 'Last Update Posted', 'Locations',
#        'URL', 'Countries', 'Country Count', 'Study Duration (days)',
#        'Intervention List', 'Age Group', 'YearMonth'],
#       dtype='object')

# %% [markdown]
# The word cloud reveals the most frequently used terms across study titles and conditions. Words like coronavirus, sars-cov, respiratory, safety, clinical etc likely dominate reflects on research themes during the pandemic.

# %%
# !pip install scikit-learn

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# Prepare title text
title_text = df['Title'].dropna().astype(str)

# Vectorize text using TF-IDF
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(title_text)

# Fit KMeans clustering
num_clusters = 5
model = KMeans(n_clusters=num_clusters, random_state=42)
model.fit(X)

# Assign cluster labels to the original data
df_clustered = title_text.to_frame(name='Title')
df_clustered['Cluster'] = model.labels_

# Print sample titles from each cluster
for i in range(num_clusters):
    print(f"\n📌 Cluster {i}:")
    print(df_clustered[df_clustered['Cluster'] == i].head(5)['Title'].to_string(index=False))
# Out:
# 📌 Cluster 0:
# Impact of COVID-19 on the Clinical Outcomes and...
# Neonatal Complications of Coronavirus Disease (...
# Evaluation of Clinical Parameters on Admission ...
# Characteristics and Outcome of Coronavirus Dise...
# Lung Ultrasound Score in Covid 19 Infectious Di...
#
# 📌 Cluster 1:
#         Maternal-foetal Transmission of SARS-Cov-2
#         Maternal-foetal Transmission of SARS-Cov-2
#         Maternal-foetal Transmission of SARS-Cov-2
# Diagnostic Performance Evaluation of a Novel SA...
# Clinical Trial to Evaluate the Safety and Immun...
#
# 📌 Cluster 2:
# LATE-COVID/LATE-COVID-Kids - Observational Stud...
# Descriptive and Retrospective Analysis of Acute...
# COVID-19 Pandemic and Parents of Disabled Children
# Evaluation of the Performance of the Covid-19 A...
#           Incidence of Covid-19 in School Children
#
# 📌 Cluster 3:
# Diagnostic Performance of the ID Now™ COVID-19 ...
# Study to Evaluate the Efficacy of COVID19-0001-...
# ...

# %% [markdown]
# The studies of similar types are segreated in groups like cluster 1 where vacines are mentioned , cluster 2 with treatments options, cluster 2 with studies on children then there is diagonistic/Analysis/Efficacy and plasma treatment in remaining 2 which gets the sentiment of the analysis from them which had help to build on the findings of others studies and even compare notes for better results.

# %% [markdown]
# **<u>Conclusions</u>**
# 1. The majority of COVID-19 clinical trials were interventional, with a focus on vaccines, treatments, and prevention.
#
# 2. Phase 2/3 studies dominate, indicating a focus on safety and efficacy evaluation.
#
# 3. Trials largely included adults of all genders, with global geographic distribution.
# 4. Top countries conducting trials: USA, China, India, and various EU nations.
# 5. Enrollment size positively influences the likelihood of completion.
#
# 6. Funding plays a significant role in determining the scale and phase of studies — industry-funded trials tend to be larger.
#
# 1. Results reporting is delayed for many trials, with only a fraction having public outcomes available.
